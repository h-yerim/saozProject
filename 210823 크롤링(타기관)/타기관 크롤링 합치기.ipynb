# %%
import pandas as pd
a= pd.read_csv('타기관 크롤링1629685752')
b= pd.read_csv('타기관 크롤링1629690714')
c= pd.read_csv('타기관 크롤링1629693135')
d= pd.read_csv('타기관 크롤링1629695901')
e= pd.read_csv('타기관 크롤링1629698205')
f= pd.read_csv('타기관 크롤링1629703139')
g=pd.read_csv('타기관 크롤링1629706964')
h=pd.read_csv('타기관 크롤링1629712226')
i=pd.read_csv('타기관 크롤링1629716433')
j=pd.read_csv('타기관 크롤링1629718796')
k=pd.read_csv('타기관 크롤링1629723731')
l=pd.read_csv('타기관 크롤링1629732801')

# %%
result=pd.concat([a,b,c,d,e,f,g,h,i,j,k,l])
result=result[['구명','시설분류','주차장명','사용상태','충전기타입','수집시간']]
result=result.sort_values(by=['구명','주차장명','수집시간'],ascending=[True,True,True])
result=result.reset_index(drop=True)
result.head()
# Out:
#     구명  시설분류          주차장명  사용상태 충전기타입                        수집시간
# 0  강남구  기타시설  (사)국가안보전략연구원   사용중    완속  2021-08-23 10:21:18.011482
# 1  강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 11:56:28.216088
# 2  강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 12:55:27.268442
# 3  강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 13:46:06.116695
# 4  강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 14:20:14.907467

# %%
result[result['주차장명']=='(사)국가안보전략연구원']
# Out:
#      구명  시설분류          주차장명  사용상태 충전기타입                        수집시간
# 0   강남구  기타시설  (사)국가안보전략연구원   사용중    완속  2021-08-23 10:21:18.011482
# 1   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 11:56:28.216088
# 2   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 12:55:27.268442
# 3   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 13:46:06.116695
# 4   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 14:20:14.907467
# 5   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 15:26:45.972287
# 6   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 16:23:16.806712
# 7   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 18:04:00.410372
# 8   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 19:04:05.676932
# 9   강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 20:04:38.262062
# 10  강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 21:04:46.080157
# 11  강남구  기타시설  (사)국가안보전략연구원  사용가능    완속  2021-08-23 23:43:30.630908

# %%
result.to_csv('210823 타기관 크롤링.csv',index=False)
